# %%
import matplotlib.pyplot as plot
f=open("plotthis","r")
for line in f:
    a=line
a=a.strip()
a=a.strip('[]').split(',')
x=[]
for i in a:
    x.append(float(i))
print x[:10]
# Out:
# [10.0, 4912.887008566777, 96209.75554542129, 99799.23270075028, 99806.43971751044, 99806.4536674344, 99806.45369443395, 99806.4536944862, 99806.45369448632, 99806.4536944863]

# %%
import matplotlib.pyplot as plot
# %matplotlib inline


plot.plot(x,'*')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-519c0e84892c> in <module>()
#       3 plot.figure(figsize=(20,10))
#       4
# ----> 5 plot.plot(x,'*')
#
# NameError: name 'x' is not defined

# %%
import pickle
r=pickle.load(open("r.p","r"))
print r
pops=pickle.load(open("testpops.p","r"))
# Out:
# {0: 0.51667222339681274, 1: 0.53093935655667512, 2: 0.54202049807204333, 3: 0.5705023723757342, 4: 0.625, 5: 0.691864311823017, 6: 0.7310202450288343, 7: 0.75}

# %%
import matplotlib.pyplot as plot


# %matplotlib inline

fig, axes = plot.subplots(1, 1, figsize=(20, 8))
for i in pops:
    ti=range(pops[i][0],pops[i][0]+len(pops[i][1]))
    axes.plot(ti,pops[i][1],'-',label=str(i))
    plot.legend()
    
plot.ylim(0.0, 1000)


   
    
#plot.figure(figsize=(20,10))
# Out:
# (0.0, 1000)
