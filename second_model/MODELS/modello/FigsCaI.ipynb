# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.animation as manimation


fig = plt.figure()
#Initial Setup
Sn='Cai'
Fn="../snaps/"+str(13035)+".000000"+Sn+".dat"
print Fn
Nk=np.loadtxt(Fn)

axes=plt.imshow(Nk)#, extent = [0,50, 100, 0] )
cax = plt.axes([0.80, 0.1, 0.04, 0.8])
zmin=0.0000
zmax=0.0014
plt.clim(zmin,zmax)
#plt.colorbar(cax=cax)
	#plt.colorbar()
fig.suptitle('$[Ca^{2+}]_i(x_n,y_n,t )$',fontsize=20)
#axes.yaxis.set_tick_params(labelsize=20)
fig.set_size_inches(18.5,10.5)
fig.savefig('Cai2png.png',dpi=500)
fig.savefig('Cai2.svg',dpi=500)
# Out:
# ../snaps/13035.000000Cai.dat

# %%
import matplotlib
matplotlib.__version__
# Out:
# u'1.5.x'

# %%
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
from matplotlib import pyplot as plt

# Generate some 3D sample data
mu_vec1 = np.array([0,0,0]) # mean vector
cov_mat1 = np.array([[1,0,0],[0,1,0],[0,0,1]]) # covariance matrix

class1_sample = np.random.multivariate_normal(mu_vec1, cov_mat1, 20)
class2_sample = np.random.multivariate_normal(mu_vec1 + 1, cov_mat1, 20)
class3_sample = np.random.multivariate_normal(mu_vec1 + 2, cov_mat1, 20)

# class1_sample.shape -> (20, 3), 20 rows, 3 columns

fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111, projection='3d')
   
ax.scatter(class1_sample[:,0], class1_sample[:,1], class1_sample[:,2], 
           marker='x', color='blue', s=40, label='class 1')
ax.scatter(class2_sample[:,0], class2_sample[:,1], class2_sample[:,2], 
           marker='o', color='green', s=40, label='class 2')
ax.scatter(class3_sample[:,0], class3_sample[:,1], class3_sample[:,2], 
           marker='^', color='red', s=40, label='class 3')

ax.set_xlabel('variable X')
ax.set_ylabel('variable Y')
ax.set_zlabel('variable Z')

plt.title('3D Scatter Plot')
     
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-760e63f8d733> in <module>()
#      14
#      15 fig = plt.figure(figsize=(8,8))
# ---> 16 ax = fig.add_subplot(111, projection='3d')
#      17
#      18 ax.scatter(class1_sample[:,0], class1_sample[:,1], class1_sample[:,2],
#
# /usr/local/lib/python2.7/dist-packages/matplotlib-1.5.x-py2.7-linux-x86_64.egg/matplotlib/figure.pyc in add_subplot(self, *args, **kwargs)
#     956                     self._axstack.remove(ax)
#     957
# --> 958             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#     959
#     960         self._axstack.add(key, a)
#
# /usr/local/lib/python2.7/dist-packages/matplotlib-1.5.x-py2.7-linux-x86_64.egg/matplotlib/axes/_subplots.pyc in __init__(self, fig, *args, **kwargs)
#      76
#      77         # _axes_class is set in the subplot_class_factory
# ---> 78         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#      79
#      80     def __reduce__(self):
#
# /usr/lib/pymodules/python2.7/mpl_toolkits/mplot3d/axes3d.pyc in __init__(self, fig, rect, *args, **kwargs)
#      89         Axes.__init__(self, fig, rect,
#      90                       frameon=True,
# ---> 91                       *args, **kwargs)
#      92         # Disable drawing of axes by base class
#      93         Axes.set_axis_off(self)
#
# /usr/local/lib/python2.7/dist-packages/matplotlib-1.5.x-py2.7-linux-x86_64.egg/matplotlib/axes/_base.pyc in __init__(self, fig, rect, axisbg, frameon, sharex, sharey, label, xscale, yscale, **kwargs)
#     434         self._hold = rcParams['axes.hold']
#     435         self._connected = {}  # a dict from events to (id, func)
# --> 436         self.cla()
#     437         # funcs used to format x and y - fall back on major formatters
#     438         self.fmt_xdata = None
#
# /usr/lib/pymodules/python2.7/mpl_toolkits/mplot3d/axes3d.pyc in cla(self)
#    1043         self._zmargin = 0
#    1044
# -> 1045         Axes.cla(self)
#    1046
#    1047         self.grid(rcParams['axes3d.grid'])
#
# /usr/local/lib/python2.7/dist-packages/matplotlib-1.5.x-py2.7-linux-x86_64.egg/matplotlib/axes/_base.pyc in cla(self)
#     895         self.containers = []
#     896
# --> 897         self.grid(self._gridOn, which=rcParams['axes.grid.which'])
#     898         props = font_manager.FontProperties(size=rcParams['axes.titlesize'],
#     899                                         weight=rcParams['axes.titleweight'])
#
# /usr/lib/pymodules/python2.7/mpl_toolkits/mplot3d/axes3d.pyc in grid(self, b, **kwargs)
#    1254         if len(kwargs) :
#    1255             b = True
# -> 1256         self._draw_grid = maxes._string_to_bool(b)
#    1257
#    1258     def ticklabel_format(self, **kwargs) :
#
# AttributeError: 'module' object has no attribute '_string_to_bool'

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.gca()
raw_input()
x, y, z = np.meshgrid(np.arange(-0.8, 1, 0.2),
                      np.arange(-0.8, 1, 0.2),
                      np.arange(-0.8, 1, 0.8))

u = np.sin(np.pi * x) * np.cos(np.pi * y) * np.cos(np.pi * z)
v = -np.cos(np.pi * x) * np.sin(np.pi * y) * np.cos(np.pi * z)
w = (np.sqrt(2.0 / 3.0) * np.cos(np.pi * x) * np.cos(np.pi * y) *
     np.sin(np.pi * z))

ax.quiver(x, y, z, u, v, w, length=0.1)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-41ea5386f4ca> in <module>()
#      15      np.sin(np.pi * z))
#      16
# ---> 17 ax.quiver(x, y, z, u, v, w, length=0.1)
#      18
#      19 plt.show()
#
# /usr/local/lib/python2.7/dist-packages/matplotlib-1.5.x-py2.7-linux-x86_64.egg/matplotlib/axes/_axes.pyc in quiver(self, *args, **kw)
#    4177         if not self._hold:
#    4178             self.cla()
# -> 4179         q = mquiver.Quiver(self, *args, **kw)
#    4180
#    4181         self.add_collection(q, autolim=True)
#
# /usr/local/lib/python2.7/dist-packages/matplotlib-1.5.x-py2.7-linux-x86_64.egg/matplotlib/quiver.pyc in __init__(self, ax, *args, **kw)
#     415         """
#     416         self.ax = ax
# --> 417         X, Y, U, V, C = _parse_args(*args)
#     418         self.X = X
#     419         self.Y = Y
#
# /usr/local/lib/python2.7/dist-packages/matplotlib-1.5.x-py2.7-linux-x86_64.egg/matplotlib/quiver.pyc in _parse_args(*args)
#     377         nr, nc = 1, U.shape[0]
#     378     else:
# --> 379         nr, nc = U.shape
#     380     if len(args) == 2:  # remaining after removing U,V,C
#     381         X, Y = [np.array(a).ravel() for a in args]
#
# ValueError: too many values to unpack
